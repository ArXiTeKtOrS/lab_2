# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace(0, 1, 5)
print(x)
y = np.linspace(0, 2, 5)
print(y)
# Out:
# [0.   0.25 0.5  0.75 1.  ]
# [0.  0.5 1.  1.5 2. ]

# %%
xg, yg = np.meshgrid(x, y)
print(xg)
print(yg)
# Out:
# [[0.   0.25 0.5  0.75 1.  ]
#  [0.   0.25 0.5  0.75 1.  ]
#  [0.   0.25 0.5  0.75 1.  ]
#  [0.   0.25 0.5  0.75 1.  ]
#  [0.   0.25 0.5  0.75 1.  ]]
# [[0.  0.  0.  0.  0. ]
#  [0.5 0.5 0.5 0.5 0.5]
#  [1.  1.  1.  1.  1. ]
#  [1.5 1.5 1.5 1.5 1.5]
#  [2.  2.  2.  2.  2. ]]

# %%
plt.plot(xg, yg, color="r", marker="*", linestyle="none")
