# %%
import numpy as np
a = [[1, 2], [3, 4]]
print(np.matrix(a))
# Out:
# [[1 2]
#  [3 4]]

# %%
b = np.array([[5, 6], [7, 8]])
print(np.matrix(b))
# Out:
# [[5 6]
#  [7 8]]

# %%
c = np.matrix('[1, 2; 3, 4]')
print(c)
# Out:
# [[1 2]
#  [3 4]]
